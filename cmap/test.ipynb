# %%
import jax.numpy as jnp
# Out:
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/razavis2/anaconda3/envs/pcmap/lib/python3.9/site-packages/traitlets/traitlets.py", line 632, in get
#     value = obj._trait_values[self.name]
# KeyError: '_control_lock'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/razavis2/anaconda3/envs/pcmap/lib/python3.9/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/Users/razavis2/anaconda3/envs/pcmap/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 301, in dispatch_control
#     async with self._control_lock:
#   File "/Users/razavis2/anaconda3/envs/pcmap/lib/python3.9/site-packages/traitlets/traitlets.py", line 687, in __get__
#     return t.cast(G, self.get(obj, cls))  # the G should encode the Optional
# ...

# %%
from Linear_model_data import make_cv_data

# %%
m0=jnp.array([5.0,5.0,0.0,0.0])
P0=0.01*jnp.eye(4)
T, X, y, Y, y_rev,yd=make_cv_data(m0, P0, nsteps=5000, dt=0.01, q=0.2, r=0.01, seed=None)

# %%
print(y(0))
print(y_rev(50-2.3))
# Out:
# [5.0257454 3.9946792]
# [4.573378 5.226295]

# %%
print(yd[2])
# Out:
# [7.1804867 4.3031807]
