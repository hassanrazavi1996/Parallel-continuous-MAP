# %%
import jax.numpy as jnp

# %%
from Linear_model_data import make_cv_data

# %%
m0=jnp.array([5.0,5.0,0.0,0.0])
P0=0.01*jnp.eye(4)
T, X, y, Y, y_rev=make_cv_data(m0, P0, nsteps=5000, dt=0.01, q=0.2, r=0.01, seed=None)

# %%
print(y(2.3))
print(y_rev(51-2.3))
# Out:
# [5.883781  4.8075895]
# [5.301053  4.8997517]
